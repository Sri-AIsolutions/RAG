# %%
import os 
from dotenv import load_dotenv
load_dotenv()
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings #to call embedding model

embeddings=OpenAIEmbeddings(
    model="text-embedding-3-small"
)

# %%
text="Iam sri, and i love to work with data and build things"
#as we r using sentence transformer --so we r converting sentence to a vector not word into a vector

embedding=embeddings.embed_query(text)
#if we r giving a single sentence --we use embed query 
#if set of sentences then we use embed_documents

print(f"text:{text}")
print(f"embedding length:{len(embedding)}") #to now the length of the vetor
print(embedding[:10])
# Out:
# text:Iam sri, and i love to work with data and build things
# embedding length:1536
# [0.030254531651735306, -0.009170010685920715, 0.018535127863287926, 0.005739385727792978, 0.0462532714009285, -0.018092885613441467, -0.004715076182037592, 0.008812314830720425, -0.0768980160355568, -0.011986048892140388]

# %%
content=[
   "Vector embeddings are numerical representations of data (like text, images, or audio) that capture their meaning in a mathematical form.",
   "They convert complex information into vectors (lists of numbers) so that machines can understand and compare them.",
   "Similar items have embeddings that are closer together in vector space, while different items are farther apart.",
   "In NLP, words or sentences with similar meanings have similar embeddings.",
   "Vector embeddings are widely used in search engines, recommendation systems, clustering, and RAG (Retrieval-Augmented Generation).",
   "They help models find relevance, similarity, and context efficiently."
]

embed=embeddings.embed_documents(content)
print(embed[0][:10])
print(embed[1][:10])
print(embed[2][:10])
print(f"length of vec:{len(embed[0])}")
#each sentence is converted into one vector
# Out:
# [-0.010021060705184937, -0.015933189541101456, -0.020219484344124794, -0.008380444720387459, 0.0225843358784914, 0.006050079595297575, 0.004939091857522726, -0.010631980374455452, 0.00011831957817776129, -0.0055081346072256565]
# [-0.03338638320565224, 0.03146420419216156, -0.019702313467860222, -0.02185332030057907, 0.056383855640888214, -0.034118641167879105, 0.005926711950451136, 0.01982817053794861, -0.0006071161478757858, 0.07057134807109833]
# [-0.03451668843626976, 0.0034668180160224438, 0.0162095595151186, 0.01594153605401516, 0.02570689283311367, -0.014368358068168163, 0.0574268214404583, -0.02341121807694435, -0.014682993292808533, 0.026452695950865746]
# length of vec:1536
